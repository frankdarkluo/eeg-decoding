# %%
with open("eeg_alpha_feats_tri.py", "r") as file:
    eeg_alpha_feats_tri_content = file.read()

exec(eeg_alpha_feats_tri_content)

# Checking the shape of eeg_X

# %%
len(eeg_X[:1])
# Out:
# [[array([0.52165885, 0.75186425, 0.84868351, 0.84346727, 0.7339058 ,
#          0.42084111, 0.56142369, 0.80113901, 0.81833252, 0.77942157,
#          0.6629613 , 0.56388827, 0.723038  , 0.73805893, 0.80636722,
#          0.78734574, 0.56948915, 0.7557272 , 0.78864681, 0.64553545,
#          0.80056364, 0.81446934, 0.73642283, 0.6318409 , 0.46240129,
#          0.68259297, 0.96071627, 0.95723909, 1.00180257, 0.86548893,
#          0.5451144 , 1.37914847, 1.29152351, 1.40326624, 1.43809027,
#          0.79740557, 1.07258231, 2.09814643, 1.8638055 , 1.70979613,
#          2.72406676, 2.10553212, 1.88574165, 1.41180726, 1.04946909,
#          0.52025366, 2.48984429, 2.73537054, 2.30039969, 1.87072633,
#          1.47983432, 1.6193069 , 2.69239816, 2.65398915, 2.28452312,
#          1.83556284, 2.45021123, 2.4416036 , 2.2029218 , 1.92389932,
#          2.39185262, 2.24717414, 1.96198839, 1.70594731, 1.25309763,
#          0.8246676 , 0.40160818, 2.26616905, 2.08606813, 1.86275629,
# ...

# %%
np.array(eeg_X[399]).shape
# Out:
# (9, 105)
